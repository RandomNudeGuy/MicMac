# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_df = pd.read_csv('/Users/mcrandom/Downloads/students (1).csv')
courses_df = pd.read_csv('/Users/mcrandom/Downloads/courses (1).csv')
course_student_df = pd.read_csv('/Users/mcrandom/Downloads/studnet_course (1).csv')
teachers_df = pd.read_csv('/Users/mcrandom/Downloads/teachers (1).csv')

# %%
students_df_copy = students_df.copy()
courses_df_copy = courses_df.copy()
course_student_df_copy = course_student_df.copy()
teachers_df_copy = teachers_df.copy()

# %%
duplicate_email_rows = students_df_copy[students_df_copy.duplicated('email', keep=False)]
duplicate_email_rows
# Out:
#       id first_name  last_name  gender   age       city          education  \
# 15    16    Sheffie     Fullom    Male  41.0      Haifa  Bachelor's degree
# 26    27   Kaitlynn    Tansley  Female  39.0   Ashkelon       No education
# 32    33     Wileen     Thirst     NaN  48.0   Ashkelon        High school
# 38    39       Neil     Lipson    Male  27.0   Ashkelon        High school
# 65    66     Juieta   Bodycote  Female  37.0   Ashkelon       No education
# 72    73   Jermaine      Gabey  Female  36.0  Jerusalem  Bachelor's degree
# 88    89      Danny  Haythorne    Male  42.0   Tel Aviv       No education
# 90    91    Opaline  Satterlee  Female  34.0   Tel Aviv    Master's degree
# 205  206      Cesar      Lghan    Male   NaN   Tel Aviv        High school
#
#                      email
# 15         sfullomf@wp.com
# 26       ktansleyq@soup.io
# 32      wthirstw@youku.com
# 38   nlipson12@foxnews.com
# 65         sfullomf@wp.com
# 72       ktansleyq@soup.io
# 88      wthirstw@youku.com
# 90   nlipson12@foxnews.com
# 205        sfullomf@wp.com

# %%
student_ids_map = {66: 16, 206: 16, 73: 27, 33: 89, 91:39}
students_df_copy.set_index('id', inplace=True)
students_df_copy
# Out:
#      first_name  last_name  gender   age         city          education  \
# id
# 1        Birgit  Mackriell  Female  15.0        Haifa       No education
# 2    Cristionna    Ferrick  Female  32.0    Bnei Brak        High school
# 3         Colin       Tite     NaN   NaN  Petah Tikva        High school
# 4         Jonis      Iston  Female  40.0    Jerusalem        High school
# 5           Dex    Goodson    Male  43.0        Haifa  Bachelor's degree
# ..          ...        ...     ...   ...          ...                ...
# 496      Karoly   Ferreres  Female  29.0        Haifa        High school
# 497      Rivkah   Androlli  Female  43.0        Haifa       No education
# 498  Melisandra     Screen  Female  34.0        Haifa        High school
# 499      Delmer      Alpin    Male   NaN        Haifa        High school
# 500      Gillan     Terram  Female  34.0        Haifa  Bachelor's degree
#
#                           email
# id
# 1      bmackriell0@china.com.cn
# 2             cferrick1@loc.gov
# 3    ctite2@businessinsider.com
# 4          jiston3@edublogs.org
# 5        dgoodson4@e-recht24.de
# ..                          ...
# 496       kferreresdr@amazon.de
# 497           randrollids@is.gd
# 498       mscreendt@booking.com
# 499     dalpindu@cloudflare.com
# 500    gterramdv@friendfeed.com
#
# [500 rows x 7 columns]

# %%
students_df_copy.drop(student_ids_map.keys(), axis=0, inplace=True)

# %%
students_df_copy
# Out:
#      first_name  last_name  gender   age         city          education  \
# id
# 1        Birgit  Mackriell  Female  15.0        Haifa       No education
# 2    Cristionna    Ferrick  Female  32.0    Bnei Brak        High school
# 3         Colin       Tite     NaN   NaN  Petah Tikva        High school
# 4         Jonis      Iston  Female  40.0    Jerusalem        High school
# 5           Dex    Goodson    Male  43.0        Haifa  Bachelor's degree
# ..          ...        ...     ...   ...          ...                ...
# 496      Karoly   Ferreres  Female  29.0        Haifa        High school
# 497      Rivkah   Androlli  Female  43.0        Haifa       No education
# 498  Melisandra     Screen  Female  34.0        Haifa        High school
# 499      Delmer      Alpin    Male   NaN        Haifa        High school
# 500      Gillan     Terram  Female  34.0        Haifa  Bachelor's degree
#
#                           email
# id
# 1      bmackriell0@china.com.cn
# 2             cferrick1@loc.gov
# 3    ctite2@businessinsider.com
# 4          jiston3@edublogs.org
# 5        dgoodson4@e-recht24.de
# ..                          ...
# 496       kferreresdr@amazon.de
# 497           randrollids@is.gd
# 498       mscreendt@booking.com
# 499     dalpindu@cloudflare.com
# 500    gterramdv@friendfeed.com
#
# [495 rows x 7 columns]

# %%
students_df_copy.reset_index('id', inplace=True)

# %%
students_df_copy
# Out:
#       id  first_name  last_name  gender   age         city          education  \
# 0      1      Birgit  Mackriell  Female  15.0        Haifa       No education
# 1      2  Cristionna    Ferrick  Female  32.0    Bnei Brak        High school
# 2      3       Colin       Tite     NaN   NaN  Petah Tikva        High school
# 3      4       Jonis      Iston  Female  40.0    Jerusalem        High school
# 4      5         Dex    Goodson    Male  43.0        Haifa  Bachelor's degree
# ..   ...         ...        ...     ...   ...          ...                ...
# 490  496      Karoly   Ferreres  Female  29.0        Haifa        High school
# 491  497      Rivkah   Androlli  Female  43.0        Haifa       No education
# 492  498  Melisandra     Screen  Female  34.0        Haifa        High school
# 493  499      Delmer      Alpin    Male   NaN        Haifa        High school
# 494  500      Gillan     Terram  Female  34.0        Haifa  Bachelor's degree
#
#                           email
# 0      bmackriell0@china.com.cn
# 1             cferrick1@loc.gov
# 2    ctite2@businessinsider.com
# 3          jiston3@edublogs.org
# 4        dgoodson4@e-recht24.de
# ..                          ...
# 490       kferreresdr@amazon.de
# 491           randrollids@is.gd
# 492       mscreendt@booking.com
# 493     dalpindu@cloudflare.com
# 494    gterramdv@friendfeed.com
#
# [495 rows x 8 columns]

# %%
course_student_df_copy['student_id'] = course_student_df_copy['student_id'].replace(student_ids_map)

# %%
course_student_df_copy[course_student_df_copy['student_id'] == 16]
# Out:
#       id  student_id  course_id  final_grade
# 18    19          16         23         83.0
# 190  191          16         31         83.0
# 390  391          16          1         66.0
# 416  417          16          6         60.0
# 432  433          16         33         52.0
# 583  584          16          7         75.0
# 606  607          16         43         87.0
# 670  671          16         21         75.0
# 753  754          16         20         61.0
# 989  990          16         15         70.0

# %%
## Exe 2 - missing data

missing_data = students_df_copy.isnull().sum()
precentage_missing = missing_data * 100 / total_rows
total_rows = students_df_copy.isnull().count()
final_missing_data = pd.concat([total_rows, missing_data, precentage_missing], axis=1, keys=['Total Rows', 'Missing Rows', 'Percentage'])
final_missing_data
# Out:
#             Total Rows  Missing Rows  Percentage
# id                 495             0         0.0
# first_name         495             0         0.0
# last_name          495             0         0.0
# gender             495             0         0.0
# age                495             0         0.0
# city               495             0         0.0
# education          495             0         0.0
# email              495             0         0.0

# %%
students_df_copy['gender'] = students_df_copy['gender'].fillna('Unknown')
students_df_copy['age'] = students_df_copy['age'].fillna(round(students_df_copy['age'].mean()))
students_df_copy
# Out:
#       id  first_name  last_name   gender   age         city  \
# 0      1      Birgit  Mackriell   Female  15.0        Haifa
# 1      2  Cristionna    Ferrick   Female  32.0    Bnei Brak
# 2      3       Colin       Tite  Unknown  35.0  Petah Tikva
# 3      4       Jonis      Iston   Female  40.0    Jerusalem
# 4      5         Dex    Goodson     Male  43.0        Haifa
# ..   ...         ...        ...      ...   ...          ...
# 490  496      Karoly   Ferreres   Female  29.0        Haifa
# 491  497      Rivkah   Androlli   Female  43.0        Haifa
# 492  498  Melisandra     Screen   Female  34.0        Haifa
# 493  499      Delmer      Alpin     Male  35.0        Haifa
# 494  500      Gillan     Terram   Female  34.0        Haifa
#
#              education                       email
# 0         No education    bmackriell0@china.com.cn
# 1          High school           cferrick1@loc.gov
# 2          High school  ctite2@businessinsider.com
# 3          High school        jiston3@edublogs.org
# 4    Bachelor's degree      dgoodson4@e-recht24.de
# ..                 ...                         ...
# 490        High school       kferreresdr@amazon.de
# 491       No education           randrollids@is.gd
# 492        High school       mscreendt@booking.com
# 493        High school     dalpindu@cloudflare.com
# 494  Bachelor's degree    gterramdv@friendfeed.com
#
# [495 rows x 8 columns]

# %%
## Exe 2 - missing data

missing_data = courses_df_copy.isnull().sum()
precentage_missing = missing_data * 100 / total_rows
total_rows = courses_df_copy.isnull().count()
final_missing_data = pd.concat([total_rows, missing_data, precentage_missing], axis=1, keys=['Total Rows', 'Missing Rows', 'Percentage'])
final_missing_data
# Out:
#                    Total Rows  Missing Rows  Percentage
# course_id                  50             0         0.0
# course_name                50             0         0.0
# course_category            50             0         0.0
# teacher_id                 50             5        10.0
# course_start_date          50             0         0.0

# %%
courses_df_copy.dropna(subset=['teacher_id'], inplace=True)
courses_df_copy
# Out:
#     course_id           course_name              course_category  teacher_id  \
# 0           1  Full Stack Developer         Software Development        30.0
# 2           3       Product Manager  Product & Business Strategy        14.0
# 3           4          AI Developer         Software Development        16.0
# 4           5       DevOps Engineer         Software Development        21.0
# 5           6          AI Developer         Software Development         7.0
# 7           8          AI Developer         Software Development        14.0
# 8           9          AI Developer         Software Development         7.0
# 9          10       DevOps Engineer         Software Development        10.0
# 10         11                 Cyber      Data Science & Security         9.0
# 11         12                 Cyber      Data Science & Security        20.0
# 12         13  Full Stack Developer         Software Development        35.0
# 13         14                    QA         Software Development         1.0
# 14         15       DevOps Engineer         Software Development        17.0
# 17         18  Full Stack Developer         Software Development        11.0
# 18         19  Full Stack Developer         Software Development        24.0
# 19         20  Full Stack Developer         Software Development        20.0
# 20         21  Full Stack Developer         Software Development        22.0
# 21         22          AI Developer         Software Development        30.0
# 22         23                 Cyber      Data Science & Security        18.0
# 23         24          AI Developer         Software Development        18.0
# 24         25                 Cyber      Data Science & Security        23.0
# 25         26                 Cyber      Data Science & Security         5.0
# 26         27  Full Stack Developer         Software Development         3.0
# 27         28  Full Stack Developer         Software Development        20.0
# 28         29          AI Developer         Software Development        28.0
# 29         30       Product Manager  Product & Business Strategy         6.0
# 30         31  Full Stack Developer         Software Development         3.0
# 31         32       Product Manager  Product & Business Strategy        28.0
# 32         33       Product Manager  Product & Business Strategy         4.0
# 33         34                 Cyber      Data Science & Security        25.0
# 34         35          AI Developer         Software Development        21.0
# 35         36       Product Manager  Product & Business Strategy        31.0
# 36         37          AI Developer         Software Development         5.0
# 37         38                 Cyber      Data Science & Security         9.0
# 38         39       DevOps Engineer         Software Development        21.0
# 39         40          AI Developer         Software Development        12.0
# 40         41       DevOps Engineer         Software Development        25.0
# 41         42       Product Manager  Product & Business Strategy        10.0
# 42         43          AI Developer         Software Development         6.0
# 43         44          AI Developer         Software Development         5.0
# 44         45          AI Developer         Software Development         9.0
# 46         47          AI Developer         Software Development         3.0
# 47         48       Product Manager  Product & Business Strategy         2.0
# 48         49                 Cyber      Data Science & Security        29.0
# 49         50  Full Stack Developer         Software Development        27.0
#
#    course_start_date
# 0         2023-08-17
# 2         2023-06-28
# 3         2023-11-21
# 4         2023-01-23
# 5         2023-12-08
# 7         2023-03-25
# 8         2023-09-09
# 9         2023-06-17
# 10        2023-10-13
# 11        2023-11-07
# 12        2023-10-20
# 13        2023-12-19
# 14        2023-10-11
# 17        2023-11-23
# 18        2023-04-03
# 19        2023-09-23
# 20        2023-08-23
# 21        2023-04-25
# 22        2023-10-04
# 23        2023-10-11
# 24        2023-05-28
# 25        2023-12-09
# 26        2023-09-28
# 27        2023-04-09
# 28        2023-04-06
# 29        2023-04-03
# 30        2023-12-23
# 31        2023-01-14
# 32        2023-12-16
# 33        2023-02-24
# 34        2023-06-22
# 35        2023-04-17
# 36        2023-02-21
# 37        2023-09-30
# 38        2023-04-07
# 39        2023-09-02
# 40        2023-02-08
# 41        2023-12-29
# 42        2023-09-12
# 43        2023-03-04
# 44        2023-06-27
# 46        2023-04-15
# 47        2023-10-17
# 48        2023-03-02
# 49        2023-09-07

# %%
course_student_df_copy = course_student_df_copy[course_student_df_copy['course_id'].isin(courses_df_copy['course_id'])]

# %%
course_student_df_copy
# Out:
#        id  student_id  course_id  final_grade
# 0       1         247         26         81.0
# 1       2         113         11          NaN
# 2       3         125          4         63.0
# 3       4         455         50         72.0
# 4       5         140          9         59.0
# ..    ...         ...        ...          ...
# 995   996          48         39          NaN
# 996   997         269         35         85.0
# 997   998          75         42         78.0
# 998   999          21          4         69.0
# 999  1000         163         14         66.0
#
# [895 rows x 4 columns]

# %%
missing_data = course_student_df_copy.isnull().sum()
precentage_missing = missing_data * 100 / total_rows
total_rows = course_student_df_copy.isnull().count()
final_missing_data = pd.concat([total_rows, missing_data, precentage_missing], axis=1, keys=['Total Rows', 'Missing Rows', 'Percentage'])
final_missing_data
# Out:
#                      Total Rows  Missing Rows  Percentage
# id                        839.0           0.0         0.0
# student_id                839.0           0.0         NaN
# course_id                 839.0           0.0         NaN
# final_grade               839.0           0.0         NaN
# first_name                  NaN           NaN         NaN
# gender                      NaN           NaN         NaN
# last_name                   NaN           NaN         NaN
# salary                      NaN           NaN         NaN
# years_of_experience         NaN           NaN         NaN

# %%
course_student_df_copy.dropna(subset=['final_grade'], inplace=True)
# Out:
# /var/folders/n_/gjr5vm515r30lns9lx2wd0140000gn/T/ipykernel_66816/2726018464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_student_df_copy.dropna(subset=['final_grade'], inplace=True)

# %%
course_student_df_copy
# Out:
#        id  student_id  course_id  final_grade
# 0       1         247         26         81.0
# 2       3         125          4         63.0
# 3       4         455         50         72.0
# 4       5         140          9         59.0
# 5       6         157         50         60.0
# ..    ...         ...        ...          ...
# 994   995         114         14         66.0
# 996   997         269         35         85.0
# 997   998          75         42         78.0
# 998   999          21          4         69.0
# 999  1000         163         14         66.0
#
# [839 rows x 4 columns]

# %%
missing_data = teachers_df_copy.isnull().sum()
precentage_missing = missing_data * 100 / total_rows
total_rows = teachers_df_copy.isnull().count()
final_missing_data = pd.concat([total_rows, missing_data, precentage_missing], axis=1, keys=['Total Rows', 'Missing Rows', 'Percentage'])
final_missing_data
# Out:
#                      Total Rows  Missing Rows  Percentage
# id                           35             0         0.0
# first_name                   35             0         0.0
# last_name                    35             0         0.0
# gender                       35             0         0.0
# years_of_experience          35             0         0.0
# salary                       35             0         0.0

# %%
teachers_df_copy['gender'] = teachers_df_copy['gender'].fillna('Unkown')
teachers_df_copy['salary'] = teachers_df_copy['salary'].fillna(round(teachers_df_copy['salary'].mean()))

# %%
df_gender_count = students_df_copy.groupby('gender').size()
df_gender_count = df_gender_count.reset_index(name = 'count')
df_gender_count
# Out:
#     gender  count
# 0   Female    212
# 1     Male    219
# 2  Unknown     64

# %%
plt.bar(df_gender_count['gender'], df_gender_count['count'])
plt.title('Number of Students by gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(students_df_copy['age'], bins= 20)
plt.title('Age Distrobution of students')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
city_counts = students_df_copy['city'].value_counts()
city_counts
# Out:
# city
# Tel Aviv         111
# Haifa             94
# Jerusalem         62
# Ashkelon          54
# Ashdod            26
# Holon             18
# Netanya           17
# Kfar Saba         16
# Herzliya          16
# Beersheba         16
# Bnei Brak         15
# Bat Yam           15
# Petah Tikva       12
# Rishon LeZion     12
# Ramat Gan         11
# Name: count, dtype: int64

# %%
courses_by_category_count_df = courses_df_copy.groupby('course_category').size()
courses_by_category_count_df = courses_by_category_count_df.reset_index(name='course count')
courses_by_category_count_df
# Out:
#                course_category  course count
# 0      Data Science & Security             8
# 1  Product & Business Strategy             7
# 2         Software Development            30

# %%
plt.figure(figsize=(12, 6))
plt.bar(courses_by_category_count_df['course_category'], courses_by_category_count_df['course count'])
plt.title('Course by category')
plt.xlabel('Course Category')
plt.ylabel('Course COunt')
plt.show()

# %%
unique_courses = courses_df_copy.groupby('course_category')['course_name'].unique()
unique_courses = unique_courses.reset_index(name= 'Courses')
unique_courses
# Out:
#                course_category  \
# 0      Data Science & Security
# 1  Product & Business Strategy
# 2         Software Development
#
#                                              Courses
# 0                                            [Cyber]
# 1                                  [Product Manager]
# 2  [Full Stack Developer, AI Developer, DevOps En...

# %%
courses_df_copy['course_start_date'] = pd.to_datetime(courses_df_copy['course_start_date'])
courses_df_copy.set_index('course_start_date', inplace=True)
df_resample = courses_df_copy.resample(rule='M')['course_name'].unique()
df_resample
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'course_start_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 courses_df_copy['course_start_date'] = pd.to_datetime(courses_df_copy['course_start_date'])
#       2 courses_df_copy.set_index('course_start_date', inplace=True)
#       3 df_resample = courses_df_copy.resample(rule='M')['course_name'].unique()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'course_start_date'

# %%
plt_df_resample = courses_df_copy.resample(rule='M')['course_name'].nunique()
plt_df_resample
# Out:
# /var/folders/n_/gjr5vm515r30lns9lx2wd0140000gn/T/ipykernel_66816/2431195766.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt_df_resample = courses_df_copy.resample(rule='M')['course_name'].nunique()
# course_start_date
# 2023-01-31    2
# 2023-02-28    3
# 2023-03-31    2
# 2023-04-30    4
# 2023-05-31    1
# 2023-06-30    3
# 2023-07-31    0
# 2023-08-31    1
# 2023-09-30    3
# 2023-10-31    5
# 2023-11-30    3
# 2023-12-31    5
# Freq: ME, Name: course_name, dtype: int64

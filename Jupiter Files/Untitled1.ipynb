# %%
import numpy as np
import pandas as pd

# %%
exel_df = pd.read_csv('/Users/mcrandom/Downloads/example (1).csv')
print(exel_df)
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
exel_df

print(exel_df.head(2))

# %%
tips = pd.read_csv('/Users/mcrandom/Downloads/tips (3).csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
new_tips = tips[["total_bill", "tip", "Payer Name"]]

# %%
new_tips["total_payment"] = new_tips["total_bill"] + new_tips["tip"]
# Out:
# /var/folders/n_/gjr5vm515r30lns9lx2wd0140000gn/T/ipykernel_98619/1604453027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_tips["total_payment"] = new_tips["total_bill"] + new_tips["tip"]

# %%
new_tips["tip_percentage"] = new_tips["tip"] / new_tips["total_payment"] * 100
# Out:
# /var/folders/n_/gjr5vm515r30lns9lx2wd0140000gn/T/ipykernel_98619/2646127186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_tips["tip_percentage"] = new_tips["tip"] / new_tips["total_payment"] * 100

# %%
new_tips
# Out:
#      total_bill   tip          Payer Name  total_payment  tip_percentage
# 0         16.99  1.01  Christy Cunningham          18.00        5.611111
# 1         10.34  1.66      Douglas Tucker          12.00       13.833333
# 2         21.01  3.50      Travis Walters          24.51       14.279886
# 3         23.68  3.31    Nathaniel Harris          26.99       12.263801
# 4         24.59  3.61        Tonya Carter          28.20       12.801418
# ..          ...   ...                 ...            ...             ...
# 239       29.03  5.92       Michael Avila          34.95       16.938484
# 240       27.18  2.00      Monica Sanders          29.18        6.854010
# 241       22.67  2.00          Keith Wong          24.67        8.107013
# 242       17.82  1.75        Dennis Dixon          19.57        8.942259
# 243       18.78  3.00     Michelle Hardin          21.78       13.774105
#
# [244 rows x 5 columns]

# %%
new_tips.drop("tip_percentage", axis=1, inplace=True)
# Out:
# /var/folders/n_/gjr5vm515r30lns9lx2wd0140000gn/T/ipykernel_98619/759449951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_tips.drop("tip_percentage", axis=1, inplace=True)

# %%
new_tips
# Out:
#      total_bill   tip          Payer Name
# 0         16.99  1.01  Christy Cunningham
# 1         10.34  1.66      Douglas Tucker
# 2         21.01  3.50      Travis Walters
# 3         23.68  3.31    Nathaniel Harris
# 4         24.59  3.61        Tonya Carter
# ..          ...   ...                 ...
# 239       29.03  5.92       Michael Avila
# 240       27.18  2.00      Monica Sanders
# 241       22.67  2.00          Keith Wong
# 242       17.82  1.75        Dennis Dixon
# 243       18.78  3.00     Michelle Hardin
#
# [244 rows x 3 columns]

# %%
movie_score_df = pd.read_csv("/Users/mcrandom/Downloads/movie_scores.csv")
movie_score_df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
myNone = np.nan

# %%
myNone
# Out:
# nan

# %%
print(myNone is np.nan)
# Out:
# True

# %%
movie_score_df['first_name'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: first_name, dtype: bool

# %%
movie_score_df[movie_score_df['first_name'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
movie_score_df.dropna()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
movie_score_df.dropna(thresh=1, axis = 1)
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df = pd.DataFrame({'A':[None, 2, 3, None, 5], 'B':[10, None, None, 40, 50], 'C':[100, None, 300, 400, None]})

# %%
df
# Out:
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0   NaN    NaN
# 2  3.0   NaN  300.0
# 3  NaN  40.0  400.0
# 4  5.0  50.0    NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
df.dropna(thresh=3, axis=1)
# Out:
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0   NaN    NaN
# 2  3.0   NaN  300.0
# 3  NaN  40.0  400.0
# 4  5.0  50.0    NaN

# %%
df.dropna(thresh=1,subset=['A']&['C'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.dropna(thresh=1,subset=['A']&['C'])
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'

# %%
df.fillna(0)
# Out:
#      A     B      C
# 0  0.0  10.0  100.0
# 1  2.0   0.0    0.0
# 2  3.0   0.0  300.0
# 3  0.0  40.0  400.0
# 4  5.0  50.0    0.0

# %%
df[df['B'].notnull()].fillna(df['B'].mean())
# Out:
#            A     B           C
# 0  33.333333  10.0  100.000000
# 3  33.333333  40.0  400.000000
# 4   5.000000  50.0   33.333333

# %%
new_df['B']
# Out:
# 0    10.0
# 3    40.0
# 4    50.0
# Name: B, dtype: float64

# %%
mpg_df = pd.read_cvs("'/Users/mcrandom/Downloads/mpg (1).csv'")
